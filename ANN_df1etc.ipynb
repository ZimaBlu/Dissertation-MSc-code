# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("df2.csv", index_col=0)
df
# Out:
#      subject         HR  sedentary mins  minutesAsleep  minutesAwake  \
# 2          2  55.814651             689            383            34
# 3          2  49.034884             638            389            89
# 4          2  47.689538             799            270            38
# 5          2  49.257612             599            417            52
# 6          2  45.982357             711            383            51
# ..       ...        ...             ...            ...           ...
# 156        2  44.463627             855            331            40
# 157        2  49.964507             680            384           102
# 158        2  57.342087             609            366            77
# 159        2  48.888857             983            223            31
# 160        2  49.276813             784            346            42
#
#      deep_sleep_in_minutes  timeInBed  restlessness  stepsToday  \
# 2                       40        417      0.152147       16074
# 3                       72        478      0.201690       17375
# 4                       35        308      0.075534       18903
# 5                       76        469      0.201717       15647
# 6                       67        434      0.137809       21991
# ..                     ...        ...           ...         ...
# 156                     14        371      0.199192        5102
# 157                     58        486      0.220145       15078
# 158                     81        443      0.173273       17133
# 159                     29        254      0.100394       13039
# 160                     46        388      0.134021       18485
#
#      very active mins  Flare
# 2                  98  False
# 3                  80   True
# 4                 128  False
# 5                 109  False
# 6                 143  False
# ..                ...    ...
# 156                72   True
# 157                91   True
# 158               109   True
# 159               115  False
# 160               152   True
#
# [152 rows x 11 columns]

# %%
print(df.shape)
df.describe().transpose()
# Out:
# (152, 11)
#                        count          mean          std          min  \
# subject                152.0      2.000000     0.000000     2.000000
# HR                     152.0     50.666041     3.791528    38.600926
# sedentary mins         152.0    691.065789   101.634240   448.000000
# minutesAsleep          152.0    349.657895    91.934911    60.000000
# minutesAwake           152.0     56.901316    23.253501     0.000000
# deep_sleep_in_minutes  152.0     50.822368    21.399419     4.000000
# timeInBed              152.0    406.559211   108.875574    65.000000
# restlessness           152.0      0.154961     0.045444     0.066079
# stepsToday             152.0  15988.848684  5621.578663  1058.000000
# very active mins       152.0    109.815789    54.041365     0.000000
#
#                                 25%           50%           75%           max
# subject                    2.000000      2.000000      2.000000      2.000000
# HR                        48.078654     51.109007     53.215467     58.498094
# sedentary mins           631.750000    671.500000    749.500000    983.000000
# minutesAsleep            335.000000    372.500000    402.250000    504.000000
# minutesAwake              44.000000     56.500000     75.000000    110.000000
# deep_sleep_in_minutes     36.750000     54.000000     65.000000    107.000000
# timeInBed                391.000000    437.000000    470.000000    563.000000
# restlessness               0.118056      0.156581      0.191062      0.250836
# stepsToday             12399.500000  16074.500000  19898.000000  31147.000000
# very active mins          73.000000    108.000000    149.250000    253.000000

# %%
target_column = ['Flare'] 
predictors = list(set(list(df.columns))-set(target_column))
df[predictors] = df[predictors]/df[predictors].max()
df.describe().transpose()
# Out:
#                        count      mean       std       min       25%  \
# subject                152.0  1.000000  0.000000  1.000000  1.000000
# HR                     152.0  0.866114  0.064815  0.659866  0.821884
# sedentary mins         152.0  0.703017  0.103392  0.455748  0.642675
# minutesAsleep          152.0  0.693766  0.182411  0.119048  0.664683
# minutesAwake           152.0  0.517285  0.211395  0.000000  0.400000
# deep_sleep_in_minutes  152.0  0.474975  0.199995  0.037383  0.343458
# timeInBed              152.0  0.722130  0.193385  0.115453  0.694494
# restlessness           152.0  0.617778  0.181172  0.263436  0.470651
# stepsToday             152.0  0.513335  0.180485  0.033968  0.398096
# very active mins       152.0  0.434055  0.213602  0.000000  0.288538
#
#                             50%       75%  max
# subject                1.000000  1.000000  1.0
# HR                     0.873687  0.909696  1.0
# sedentary mins         0.683113  0.762462  1.0
# minutesAsleep          0.739087  0.798115  1.0
# minutesAwake           0.513636  0.681818  1.0
# deep_sleep_in_minutes  0.504673  0.607477  1.0
# timeInBed              0.776199  0.834813  1.0
# restlessness           0.624236  0.761702  1.0
# stepsToday             0.516085  0.638842  1.0
# very active mins       0.426877  0.589921  1.0

# %%
X = df[predictors].values
y = df[target_column].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=40)

print(X_train.shape); print(X_test.shape)
# Out:
# (106, 10)
# (46, 10)

# %%
df = df.reset_index()

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(8,8,8), activation='relu', solver='adam', max_iter=500)
mlp.fit(X_train,y_train.ravel())
predict_train = mlp.predict(X_train)
predict_test = mlp.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_train,predict_train))
# Out:
# [[ 0 47]
#  [ 0 59]]

# %%
print(classification_report(y_train,predict_train))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        47
#         True       0.56      1.00      0.72        59
#
#     accuracy                           0.56       106
#    macro avg       0.28      0.50      0.36       106
# weighted avg       0.31      0.56      0.40       106
# C:\Users\bensk\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bensk\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bensk\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(confusion_matrix(y_test,predict_test))
# Out:
# array([[ 0, 21],
#        [ 0, 25]], dtype=int64)

# %%
print(classification_report(y_test,predict_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        21
#         True       0.54      1.00      0.70        25
#
#     accuracy                           0.54        46
#    macro avg       0.27      0.50      0.35        46
# weighted avg       0.30      0.54      0.38        46
# C:\Users\bensk\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bensk\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bensk\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
